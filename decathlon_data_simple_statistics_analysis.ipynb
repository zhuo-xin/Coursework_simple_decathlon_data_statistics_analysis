# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from scipy import stats

df= pd.read_csv('decathlon.csv')

# %%
df.head()
# Out:
#    Totalpoints    DecathleteName Nationality   m100  Longjump  Shotput  \
# 0         8559      Torsten Voss         DDR  10.66      8.00    14.73
# 1         8504      Uwe Freimuth         DDR  11.10      7.66    16.30
# 2         8440   Siegfried Wentz         BRD  11.21      7.22    15.84
# 3         8409  Aleksandr Nevski          SU  10.95      7.35    14.99
# 4         8381        John Sayre         USA  10.86      7.41    14.22
#
#    Highjump   m400  m110hurdles  Discus  ...  P100m   Plj  Psp  Phj  P400m  \
# 0      2.06  48.28        14.50   43.28  ...    938  1061  773  859    896
# 1      1.94  48.46        14.77   47.72  ...    839   975  870  749    887
# 2      2.09  47.75        14.28   45.52  ...    814   866  841  887    921
# 3      2.08  49.29        14.76   46.12  ...    872   898  789  878    848
# 4      2.00  49.98        14.84   46.08  ...    892   913  742  803    816
#
#    P110h   Ppv  Pdt  Pjt  P1500
# 0    911   880  732  757    752
# ...

# %%
import seaborn as sns
sns.regplot('m100','P100m',data=df)

# %%
sns.regplot('P100m','P110h',data=df)

# %%
sns.regplot('P100m','P1500',data=df)

# %%
sns.regplot('P400m','P110h',data=df)

# %%
sns.regplot('Pjt','Pdt',data=df)

# %%
sns.regplot('Psp','Pjt',data=df)

# %%
sns.regplot('Psp','Pdt',data=df)

# %%
df.sort_values(by='Psp',ascending=False).head(10)
# Out:
#       Totalpoints    DecathleteName Nationality   m100  Longjump  Shotput  \
# 4239         8555     Michael Smith         CAN  11.04      7.52    17.45
# 2096         7815   Bengt Jaerlsjoe         SWE  11.18      6.75    17.35
# 2059         8306  Antonio Penalver         SPA  11.20      7.55    17.32
# 3517         8011    Norbert Demmel         GER  11.54      6.93    17.19
# 684          8134     Robert Muzzio         USA  10.88      7.15    17.00
# 2771         8237     Robert Muzzio         USA  11.11      6.72    16.99
# 2063         8224     William Motti         FRA  11.28      7.48    16.96
# 1391         7732   Bengt Jaerlsjoe         SWE  11.46      6.80    16.94
# 3852         8626     Michael Smith         CAN  11.23      7.72    16.94
# 3864         8307  Antonio Penalver         SPA  10.95      7.27    16.91
#
#       Highjump   m400  m110hurdles  Discus  ...  P100m  Plj  Psp  Phj  P400m  \
# ...

# %%
df_perfomance=df.loc[:,'m100':'m1500']

# %%
df_perfomance.hist(layout=(2,5),figsize=(20,8),grid=True,bins=45)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000001786F205AC8>,
# ...
#       dtype=object)

# %%
from scipy.stats import normaltest
normaltest(df['Ppv'],axis=0)
# Out:
# NormaltestResult(statistic=9.250936261463115, pvalue=0.00979906671766813)

# %%
import scipy.stats
print('normality test of P100m is:',scipy.stats.shapiro(df['P100m']))
# Out:
# normality test of P100m is: (0.9991306662559509, 0.00037142334622330964)

# %%
print('normality test of 100m performance is:',scipy.stats.shapiro(df['m100']))
print('normality test of Longjump performance is:',scipy.stats.shapiro(df['Longjump']))
print('normality test of Shotput performance is:',scipy.stats.shapiro(df['Shotput']))
print('normality test of Highjump performance is:',scipy.stats.shapiro(df['Highjump']))
print('normality test of m400 performance is:',scipy.stats.shapiro(df['m400']))
print('normality test of m110hurdles performance is:',scipy.stats.shapiro(df['m110hurdles']))
print('normality test of Discus performance is:',scipy.stats.shapiro(df['Discus']))
print('normality test of Polevault performance is:',scipy.stats.shapiro(df['Polevault']))
print('normality test of Javelin performance is:',scipy.stats.shapiro(df['Javelin']))
print('normality test of m1500 performance is:',scipy.stats.shapiro(df['m1500']))
# Out:
# normality test of 100m performance is: (0.9997519850730896, 0.4854573905467987)
# normality test of Longjump performance is: (0.9982581734657288, 8.847079868701258e-08)
# normality test of Shotput performance is: (0.9987266063690186, 5.700686870113714e-06)
# normality test of Highjump performance is: (0.9971030354499817, 2.4248778332514043e-11)
# normality test of m400 performance is: (0.9964473247528076, 5.463791311749455e-13)
# normality test of m110hurdles performance is: (0.9948133826255798, 2.2382194474616685e-16)
# normality test of Discus performance is: (0.9986270070075989, 2.226269543825765e-06)
# normality test of Polevault performance is: (0.9942148327827454, 1.956914114675901e-17)
# normality test of Javelin performance is: (0.9983885884284973, 2.6512870476835815e-07)
# normality test of m1500 performance is: (0.9627954959869385, 4.728541538017663e-41)

# %%
scipy.stats.anderson(df['Pdt'], dist='norm')
# Out:
# AndersonResult(statistic=3.465010342973983, critical_values=array([0.576, 0.656, 0.787, 0.918, 1.091]), significance_level=array([15. , 10. ,  5. ,  2.5,  1. ]))

# %%
from scipy import stats
print(stats.kstest(df['P100m'], 'norm', (807,61)))
print(stats.kstest(df['Plj'], 'norm', (807,75)))
print(stats.kstest(df['Psp'], 'norm', (675,76)))
# Out:
# KstestResult(statistic=0.020979251180355596, pvalue=0.0017985972079039853)
# KstestResult(statistic=0.024777502947567753, pvalue=0.00011274791423695765)
# KstestResult(statistic=0.01971080876575576, pvalue=0.004093956077280113)

# %%
df_points_corr=df_points.corr()
df_points_corr
# Out:
#           P100m       Plj       Psp       Phj     P400m     P110h       Ppv  \
# P100m  1.000000  0.487152  0.157911  0.125804  0.575135  0.455773  0.173532
# Plj    0.487152  1.000000  0.252856  0.362483  0.312138  0.387591  0.273288
# Psp    0.157911  0.252856  1.000000  0.158077  0.035908  0.259180  0.254252
# Phj    0.125804  0.362483  0.158077  1.000000  0.109010  0.258013  0.192408
# P400m  0.575135  0.312138  0.035908  0.109010  1.000000  0.384480  0.132951
# P110h  0.455773  0.387591  0.259180  0.258013  0.384480  1.000000  0.292208
# Ppv    0.173532  0.273288  0.254252  0.192408  0.132951  0.292208  1.000000
# Pdt    0.124986  0.200344  0.719170  0.146036  0.039376  0.230503  0.273059
# Pjt    0.064606  0.176811  0.438202  0.069671  0.024954  0.137086  0.195553
# P1500 -0.083814 -0.017750 -0.109068  0.010426  0.378522  0.007814  0.012263
#
#             Pdt       Pjt     P1500
# P100m  0.124986  0.064606 -0.083814
# Plj    0.200344  0.176811 -0.017750
# ...

# %%
import scipy.stats as stat
stats.pearsonr(df['Psp'],df['Pdt'])

# %%
# first number is Pearson's correlation coefficient, the second is P-value 

print('test result of 100 metres and 400 metres is:',stats.pearsonr(df['P400m'],df['P100m']))
print('test result of 100 metres and 110-metre hurdles is:',stats.pearsonr(df['P110h'],df['P100m']))
print('test result of 100 metres and 1500 metres is:',stats.pearsonr(df['P400m'],df['P1500']))
print('test result of 400 metres and 110-metre hurdles is:',stats.pearsonr(df['P400m'],df['P110h']))
print('test result of discus and javelin is:',stats.pearsonr(df['Pdt'],df['Pjt']))
print('test result of high jump and long jump is:',stats.pearsonr(df['Phj'],df['Plj']))
print('test result of shotput and javelin is:',stats.pearsonr(df['Psp'],df['Pjt']))
print('test result of shotput and discus is:',stats.pearsonr(df['Psp'],df['Pdt']))
# Out:
# test result of 100 metres and 400 metres is: (0.5751349481945014, 0.0)
# test result of 100 metres and 110-metre hurdles is: (0.45577250244098044, 0.0)
# test result of 100 metres and 1500 metres is: (0.37852215045967824, 7.451307511300252e-270)
# test result of 400 metres and 110-metre hurdles is: (0.3844801095705271, 4.5959842340710334e-279)
# test result of discus and javelin is: (0.4184007947724799, 0.0)
# test result of high jump and long jump is: (0.3624829075895545, 5.287535105599863e-246)
# test result of shotput and javelin is: (0.438202375745773, 0.0)
# test result of shotput and discus is: (0.7191695153564529, 0.0)

# %%
import seaborn as sns
sns.pairplot(df, x_vars=['Pdt'], y_vars='Psp', size=8, aspect=2, kind='reg')
# Out:
# D:\anacoda\lib\site-packages\seaborn\axisgrid.py:2065: UserWarning: The `size` parameter has been renamed to `height`; pleaes update your code.
#   warnings.warn(msg, UserWarning)

# %%
y_pred = linreg.predict(X_test)
from sklearn import metrics
# 用scikit-learn计算MSE

# %%
print("MSE:",metrics.mean_squared_error(y_test, y_pred))

# %%
# 用scikit-learn计算RMSE
print("RMSE:",np.sqrt(metrics.mean_squared_error(y_test, y_pred)))

# %%
import statsmodels.api as sm

# %%
fit = sm.OLS.from_formula('Pdt ~ Psp', df_points).fit()

# %%
print(fit.summary())

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from scipy import stats

# %%
plt.hist(df['P100m'])
# Out:
# (array([  20.,  149.,  673., 1578., 2319., 1830., 1009.,  321.,   57.,
#           12.]),
#  array([ 597. ,  641.5,  686. ,  730.5,  775. ,  819.5,  864. ,  908.5,
#          953. ,  997.5, 1042. ]),
#  <a list of 10 Patch objects>)

# %%
x=df['P100m']
sns.distplot(x, bins=30)

# %%
df.groupby('Nationality').mean().sort_values(by='m100').head(10)
# Out:
#              Totalpoints       m100  Longjump    Shotput  Highjump       m400  \
# Nationality
# BAR          7678.000000  10.690000  7.513333  12.210000  2.076667  48.876667
# JAM          7707.058824  10.868235  7.048824  14.605882  2.006471  49.327647
# GRN          7199.500000  10.900000  7.075000  14.590000  1.795000  51.425000
# PRI          7577.666667  10.903333  7.060000  14.276667  1.893333  49.173333
# STL          7495.500000  10.960000  7.077500  12.082500  1.962500  48.745000
# CIV          6936.333333  10.966667  6.716667  10.420000  1.973333  51.400000
# QAT          7428.000000  11.010000  7.044000  13.208000  1.776000  49.318000
# CYP          7321.222222  11.028889  7.021111  13.537778  1.947778  51.177778
# TUN          7484.555556  11.029444  7.173333  11.787778  1.890556  48.326667
# NZ           7286.166667  11.040000  7.033333  12.888333  1.920000  50.388333
#
#              m110hurdles     Discus  Polevault    Javelin  ...       P100m  \
# ...

# %%
df3=df[['Totalpoints','Nationality','yearEvent']]

# %%
df3=df3.loc[df.groupby('yearEvent')['Totalpoints'].idxmax()].sort_values(by='Nationality',ascending=False) #每一年的冠军
df3= df3.set_index(['Nationality'])
df3
# Out:
#              Totalpoints  yearEvent
# Nationality
# USA                 8824       1996
# USA                 8891       1992
# USA                 8732       2005
# USA                 8755       1998
# USA                 8695       1995
# USA                 8817       1993
# USA                 8677       2006
# USA                 8844       1991
# USA                 8600       1990
# USA                 8549       1989
# GBR                 8811       1986
# FRA                 8512       1988
# DDR                 8680       1987
# DDR                 8559       1985
# CZE                 8837       1997
# CZE                 8994       1999
# CZE                 8900       2000
# CZE                 9026       2001
# CZE                 8800       2002
# CZE                 8807       2003
# CZE                 8893       2004
# BLR                 8735       1994

# %%
df2 = df.set_index(['yearEvent','Nationality'])
df2
# Out:
#                        Totalpoints               DecathleteName   m100  \
# yearEvent Nationality
# 1985      DDR                 8559                 Torsten Voss  10.66
#           DDR                 8504                 Uwe Freimuth  11.10
#           BRD                 8440              Siegfried Wentz  11.21
#           SU                  8409             Aleksandr Nevski  10.95
#           USA                 8381                   John Sayre  10.86
#           SU                  8366              Vadim Podmaryov  11.09
#           SU                  8345             Yuri II Kutsenko  11.22
#           FRA                 8306                William Motti  11.03
#           USA                 8294                Michael Ramos  10.86
#           BRD                 8223             Guido Kratschmer  11.01
#           FRA                 8211            Christian Plaziat  10.78
#           SU                  8206                 Sergei Popov  11.47
# ...

# %%
df2['Totalpoints'].max(level=1)
# Out:
# Nationality
# DDR    8680
# BRD    8730
# SU     8437
# USA    8891
# FRA    8574
# EST    8815
# POL    8566
# NED    8447
# SUI    8244
# BUL    7887
# BEL    7950
# GBR    8811
# TPE    7739
# NOR    8160
# GRE    8069
# ROM    7714
# FIN    8730
# SWE    8403
# CSR    8627
# AUS    8490
# HUN    8554
# AUT    8320
# LUX    7484
# DEN    7994
# ARG    7911
# JAP    7995
# PUR    7360
# ITA    8169
# ISL    8470
# NZL    8267
#        ...
# ICE    8583
# SWI    8153
# NZ     8007
# SLN    7659
# SAF    7469
# TVN    7543
# RU     7214
# DAN    7361
# SLK    7799
# IRE    7440
# IRN    6986
# QAT    7730
# EGY    7400
# MAS    7095
# SYR    6905
# RUM    7329
# PRI    7704
# SEN    7211
# LIT    7215
# SAU    7235
# IND    7502
# MLD    6839
# GUA    7448
# UGA    6805
# VIE    7213
# COL    7383
# GRN    7550
# IRI    7490
# KOR    7824
# MDA    7562
# Name: Totalpoints, Length: 107, dtype: int64

# %%
df.drop_duplicates(['Nationality'])
# Out:
#       Totalpoints              DecathleteName Nationality   m100  Longjump  \
# 0            8559                Torsten Voss         DDR  10.66      8.00
# 2            8440             Siegfried Wentz         BRD  11.21      7.22
# 3            8409            Aleksandr Nevski          SU  10.95      7.35
# 4            8381                  John Sayre         USA  10.86      7.41
# 7            8306               William Motti         FRA  11.03      7.63
# 16           8132              Valter Kuelvet         EST  11.21      6.90
# 20           8105           Marek Kubiszewski         POL  10.87      7.20
# 33           7909               Enno Tjepkema         NED  10.77      7.21
# 36           7894            Christian Gugler         SUI  11.53      7.16
# 37           7887            Cecko Mitrakiyev         BUL  11.24      7.11
# 50           7770              Roland Marloye         BEL  11.02      7.46
# ...

# %%
import statsmodels.api as sm
import statsmodels.formula.api as smf

# %%
fit = smf.ols('Plj ~ Longjump', df).fit()

# %%
print(fit.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                    Plj   R-squared:                       1.000
# Model:                            OLS   Adj. R-squared:                  1.000
# Method:                 Least Squares   F-statistic:                 2.190e+07
# Date:                Wed, 08 Jan 2020   Prob (F-statistic):               0.00
# Time:                        11:09:48   Log-Likelihood:                -14191.
# No. Observations:                7968   AIC:                         2.839e+04
# Df Residuals:                    7966   BIC:                         2.840e+04
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept   -846.0824      0.354  -2392.101      0.000    -846.776    -845.389
# ...

# %%
from __future__ import print_function
import numpy as np
from scipy import stats
import statsmodels.api as sm
import matplotlib.pyplot as plt
from statsmodels.sandbox.regression.predstd import wls_prediction_std
from statsmodels.iolib.table import (SimpleTable, default_txt_fmt)
np.random.seed(1024)

# %%
X=df.loc[:,'m100']
X = sm.add_constant(X)
# Out:
# D:\anacoda\lib\site-packages\numpy\core\fromnumeric.py:2389: FutureWarning: Method .ptp is deprecated and will be removed in a future version. Use numpy.ptp instead.
#   return ptp(axis=axis, out=out, **kwargs)

# %%
x = np.linspace(8, 16, 7968)

# %%
y=df.loc[:,'P100m']

# %%
model = sm.OLS(y, X)
results = model.fit()
print(results.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                  P100m   R-squared:                       0.999
# Model:                            OLS   Adj. R-squared:                  0.999
# Method:                 Least Squares   F-statistic:                 1.310e+07
# Date:                Sun, 22 Dec 2019   Prob (F-statistic):               0.00
# Time:                        16:22:37   Log-Likelihood:                -14572.
# No. Observations:                7968   AIC:                         2.915e+04
# Df Residuals:                    7966   BIC:                         2.916e+04
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       3238.5945      0.672   4818.985      0.000    3237.277    3239.912
# ...

# %%
df.columns
# Out:
# Index(['Totalpoints', 'DecathleteName', 'Nationality', 'm100', 'Longjump',
#        'Shotput', 'Highjump', 'm400', 'm110hurdles', 'Discus', 'Polevault',
#        'Javelin', 'm1500', 'yearEvent', 'P100m', 'Plj', 'Psp', 'Phj', 'P400m',
#        'P110h', 'Ppv', 'Pdt', 'Pjt', 'P1500'],
#       dtype='object')

# %%
fit = smf.ols('Plj ~ Longjump', df).fit()
print(fit.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                    Plj   R-squared:                       1.000
# Model:                            OLS   Adj. R-squared:                  1.000
# Method:                 Least Squares   F-statistic:                 2.190e+07
# Date:                Wed, 08 Jan 2020   Prob (F-statistic):               0.00
# Time:                        11:17:13   Log-Likelihood:                -14191.
# No. Observations:                7968   AIC:                         2.839e+04
# Df Residuals:                    7966   BIC:                         2.840e+04
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept   -846.0824      0.354  -2392.101      0.000    -846.776    -845.389
# ...

# %%
sns.residplot(x="Longjump", y="Plj", data=df);

# %%
ax.axis((-0.05, 2, -1, 25))
# Out:
# (-0.05, 2, -1, 25)

# %%
sm.stats.diagnostic.het_white(fit.resid, exog = fit.model.exog)
# Out:
# (4703.896187904552, 0.0, 5739.176094495512, 0.0)

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-27-22fbe38125c1> in <module>
# ----> 1 sm.stats.diagnostic.het_breushpagan(fit.resid, exog_het = fit.model.exog)
#
# AttributeError: module 'statsmodels.stats.diagnostic' has no attribute 'het_breushpagan'

# %%
fit = sm.OLS.from_formula('Totalpoints ~ m100+Longjump+Shotput+Highjump+m400+m110hurdles+Discus+Polevault+Javelin+m1500', df).fit()

# %%
print(fit.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:            Totalpoints   R-squared:                       1.000
# Model:                            OLS   Adj. R-squared:                  1.000
# Method:                 Least Squares   F-statistic:                 2.002e+06
# Date:                Tue, 17 Dec 2019   Prob (F-statistic):               0.00
# Time:                        21:36:40   Log-Likelihood:                -28111.
# No. Observations:                7968   AIC:                         5.624e+04
# Df Residuals:                    7957   BIC:                         5.632e+04
# Df Model:                          10
# Covariance Type:            nonrobust
# ...
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# Intercept    8532.1659      6.667   1279.813      0.000    8519.097    8545.234
# ...
